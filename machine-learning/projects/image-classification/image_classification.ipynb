# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
import tensorflow as tf

on_hot_encode = []

def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    return x/255

#test_shape = (np.random.choice(range(1000)), 32, 32, 3)
#test_numbers = np.random.choice(range(256), test_shape)
#print (test_numbers)
#print (normalize(test_numbers))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# **Hint:**
#
# Look into LabelBinarizer in the preprocessing module of sklearn.

# %%
from sklearn import preprocessing
np.random.seed(7)

encoding_map = range(10)

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    lb = preprocessing.LabelBinarizer()
    x_one_hot = lb.fit(encoding_map)
    x_one_hot = lb.transform(x)
    return x_one_hot

test_shape = np.random.choice(range(1000))
test_numbers = np.random.choice(range(10), test_shape)
#print (test_numbers)
#x1hot = one_hot_encode(test_numbers)
#print (x1hot)
print (type(x1hot))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# <class 'numpy.ndarray'>
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
image_size = 32 * 32
n_channels = 3
n_labels = 10


import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    x = tf.placeholder("float", [None, 32, 32, 3], name='x')
    
    return x


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    y = tf.placeholder("float", [None, n_labels], name='y')
    return y


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    keep_prob = tf.placeholder(tf.float32,name='keep_prob')
    return keep_prob


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.
#
# ** Hint: **
#
# When unpacking values as an argument in Python, look into the [unpacking](https://docs.python.org/3/tutorial/controlflow.html#unpacking-argument-lists) operator.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    # [patch_size, patch_size, num_channels, depth]
    print ("num channels: {}".format(x_tensor.get_shape().as_list()[-1]))
    F_W = tf.Variable(tf.truncated_normal([*conv_ksize, x_tensor.get_shape().as_list()[-1], conv_num_outputs], stddev=1/conv_num_outputs))
    F_b = tf.Variable(tf.zeros([conv_num_outputs]))
    conv_layer = tf.nn.conv2d(x_tensor, F_W, strides=[1, *conv_strides, 1], padding='SAME')
    # Add bias
    conv_layer = tf.nn.bias_add(conv_layer, F_b)
    # Apply activation function
    conv_layer = tf.nn.relu(conv_layer)
    
    pool = tf.nn.max_pool(conv_layer, ksize=[1, 2, 2, 1], strides=[1, *pool_strides, 1], padding='SAME')

    return pool 

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# num channels: 5
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
batch_size = 128

def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    #output = np.reshape(x_tensor, image_size, -1)
    #return output
    flat_shape = np.prod(x_tensor.get_shape().as_list()[1:])
    return tf.reshape(x_tensor,[-1,flat_shape])


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    weight = tf.Variable(tf.truncated_normal([
        x_tensor.get_shape().as_list()[1],
        num_outputs], stddev=1/num_outputs)) # 1.0/math.sqrt(num_outputs)
    bias = tf.Variable(tf.constant(0.05, shape=[num_outputs]))
    
    # Matrix multiplication input and weight, then add bias
    fc_layer = tf.matmul(x_tensor, weight) + bias
    # Apply activation function
    fc_layer = tf.nn.relu(fc_layer)
    
    return fc_layer

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    weight = tf.Variable(tf.truncated_normal([
        x_tensor.get_shape().as_list()[1],
        num_outputs], stddev=1/num_outputs)) # # 1.0/math.sqrt(num_outputs)
    bias = tf.Variable(tf.constant(0.05,shape=[num_outputs]))
    
    # Matrix multiplication input and weight, then add bias
    output_layer = tf.matmul(x_tensor, weight) + bias
    
    return output_layer

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv_layer1 = conv2d_maxpool(x, 32, (3,3), (2,2), (2,2), (2,2))
    conv_layer2 = conv2d_maxpool(conv_layer1, 32, (3,3), (2,2), (2,2), (2,2))
    conv_layer3 = conv2d_maxpool(conv_layer2, 32, (3,3), (2,2), (2,2), (2,2))
    

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    flat_layer = flatten(conv_layer3)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    fully_conn_layer1 = fully_conn(flat_layer, 512)
    fully_conn_layer1 = tf.nn.dropout(fully_conn_layer1, keep_prob)
#    fully_conn_layer2 = fully_conn(fully_conn_layer1, 256)
#    fully_conn_layer2 = tf.nn.dropout(fully_conn_layer2, keep_prob)
    
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    return output(fully_conn_layer1, n_labels)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate = 0.001).minimize(cost)
#optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(cost)


# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# num channels: 3
# num channels: 32
# num channels: 32
# num channels: 3
# num channels: 32
# num channels: 32
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x: feature_batch,
                                      y: label_batch,
                                      keep_prob: keep_probability})

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost, feed_dict={x:feature_batch, y:label_batch, keep_prob: keep_probability})
    valid_acc = sess.run(accuracy, feed_dict={x: valid_features,y: valid_labels, keep_prob: keep_probability})
    print('Loss: {:>10.4f} Validation Accuracy: {:.6f}'.format(loss, valid_acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 50
batch_size = 128
keep_probability = 0.9

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    #sess.run(tf.global_variables_initializer())
    sess.run(tf.initialize_all_variables())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.2232 Validation Accuracy: 0.238400
# Epoch  2, CIFAR-10 Batch 1:  Loss:     2.2050 Validation Accuracy: 0.271000
# Epoch  3, CIFAR-10 Batch 1:  Loss:     2.1667 Validation Accuracy: 0.316000
# Epoch  4, CIFAR-10 Batch 1:  Loss:     2.1334 Validation Accuracy: 0.342600
# Epoch  5, CIFAR-10 Batch 1:  Loss:     2.1011 Validation Accuracy: 0.355800
# Epoch  6, CIFAR-10 Batch 1:  Loss:     2.0779 Validation Accuracy: 0.365000
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.9953 Validation Accuracy: 0.380400
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.9458 Validation Accuracy: 0.388000
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.9533 Validation Accuracy: 0.390800
# Epoch 10, CIFAR-10 Batch 1:  Loss:     1.8633 Validation Accuracy: 0.394200
# Epoch 11, CIFAR-10 Batch 1:  Loss:     1.8155 Validation Accuracy: 0.409000
# Epoch 12, CIFAR-10 Batch 1:  Loss:     1.7812 Validation Accuracy: 0.419600
# Epoch 13, CIFAR-10 Batch 1:  Loss:     1.7472 Validation Accuracy: 0.425200
# Epoch 14, CIFAR-10 Batch 1:  Loss:     1.6836 Validation Accuracy: 0.429800
# Epoch 15, CIFAR-10 Batch 1:  Loss:     1.6645 Validation Accuracy: 0.436400
# Epoch 16, CIFAR-10 Batch 1:  Loss:     1.6116 Validation Accuracy: 0.434800
# Epoch 17, CIFAR-10 Batch 1:  Loss:     1.5893 Validation Accuracy: 0.441200
# Epoch 18, CIFAR-10 Batch 1:  Loss:     1.5400 Validation Accuracy: 0.443800
# Epoch 19, CIFAR-10 Batch 1:  Loss:     1.5103 Validation Accuracy: 0.444400
# Epoch 20, CIFAR-10 Batch 1:  Loss:     1.4948 Validation Accuracy: 0.443600
# Epoch 21, CIFAR-10 Batch 1:  Loss:     1.5032 Validation Accuracy: 0.451800
# Epoch 22, CIFAR-10 Batch 1:  Loss:     1.4683 Validation Accuracy: 0.453800
# Epoch 23, CIFAR-10 Batch 1:  Loss:     1.4461 Validation Accuracy: 0.455600
# Epoch 24, CIFAR-10 Batch 1:  Loss:     1.4117 Validation Accuracy: 0.460000
# Epoch 25, CIFAR-10 Batch 1:  Loss:     1.4023 Validation Accuracy: 0.458800
# Epoch 26, CIFAR-10 Batch 1:  Loss:     1.4040 Validation Accuracy: 0.455400
# Epoch 27, CIFAR-10 Batch 1:  Loss:     1.3972 Validation Accuracy: 0.456600
# Epoch 28, CIFAR-10 Batch 1:  Loss:     1.3993 Validation Accuracy: 0.458800
# Epoch 29, CIFAR-10 Batch 1:  Loss:     1.3730 Validation Accuracy: 0.459800
# Epoch 30, CIFAR-10 Batch 1:  Loss:     1.3234 Validation Accuracy: 0.466600
# Epoch 31, CIFAR-10 Batch 1:  Loss:     1.2913 Validation Accuracy: 0.472200
# Epoch 32, CIFAR-10 Batch 1:  Loss:     1.2929 Validation Accuracy: 0.473000
# Epoch 33, CIFAR-10 Batch 1:  Loss:     1.2730 Validation Accuracy: 0.477400
# Epoch 34, CIFAR-10 Batch 1:  Loss:     1.2479 Validation Accuracy: 0.480000
# Epoch 35, CIFAR-10 Batch 1:  Loss:     1.1925 Validation Accuracy: 0.484400
# Epoch 36, CIFAR-10 Batch 1:  Loss:     1.1995 Validation Accuracy: 0.484600
# Epoch 37, CIFAR-10 Batch 1:  Loss:     1.1657 Validation Accuracy: 0.487000
# Epoch 38, CIFAR-10 Batch 1:  Loss:     1.1727 Validation Accuracy: 0.485400
# Epoch 39, CIFAR-10 Batch 1:  Loss:     1.1783 Validation Accuracy: 0.491200
# Epoch 40, CIFAR-10 Batch 1:  Loss:     1.1158 Validation Accuracy: 0.491000
# Epoch 41, CIFAR-10 Batch 1:  Loss:     1.1037 Validation Accuracy: 0.494600
# Epoch 42, CIFAR-10 Batch 1:  Loss:     1.1137 Validation Accuracy: 0.496600
# Epoch 43, CIFAR-10 Batch 1:  Loss:     1.0753 Validation Accuracy: 0.493000
# Epoch 44, CIFAR-10 Batch 1:  Loss:     1.0880 Validation Accuracy: 0.495000
# Epoch 45, CIFAR-10 Batch 1:  Loss:     1.0558 Validation Accuracy: 0.499400
# Epoch 46, CIFAR-10 Batch 1:  Loss:     1.0518 Validation Accuracy: 0.498000
# Epoch 47, CIFAR-10 Batch 1:  Loss:     1.0362 Validation Accuracy: 0.499000
# Epoch 48, CIFAR-10 Batch 1:  Loss:     1.0400 Validation Accuracy: 0.501200
# Epoch 49, CIFAR-10 Batch 1:  Loss:     1.0084 Validation Accuracy: 0.500800
# Epoch 50, CIFAR-10 Batch 1:  Loss:     1.0061 Validation Accuracy: 0.494800

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    #sess.run(tf.global_variables_initializer())
    sess.run(tf.initialize_all_variables())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.1845 Validation Accuracy: 0.244000
# Epoch  1, CIFAR-10 Batch 2:  Loss:     1.9938 Validation Accuracy: 0.281600
# Epoch  1, CIFAR-10 Batch 3:  Loss:     1.6919 Validation Accuracy: 0.323600
# Epoch  1, CIFAR-10 Batch 4:  Loss:     1.7482 Validation Accuracy: 0.350800
# Epoch  1, CIFAR-10 Batch 5:  Loss:     1.7136 Validation Accuracy: 0.368000
# Epoch  2, CIFAR-10 Batch 1:  Loss:     2.0318 Validation Accuracy: 0.397000
# Epoch  2, CIFAR-10 Batch 2:  Loss:     1.7764 Validation Accuracy: 0.396800
# Epoch  2, CIFAR-10 Batch 3:  Loss:     1.3837 Validation Accuracy: 0.397000
# Epoch  2, CIFAR-10 Batch 4:  Loss:     1.6023 Validation Accuracy: 0.432200
# Epoch  2, CIFAR-10 Batch 5:  Loss:     1.5135 Validation Accuracy: 0.445400
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.8263 Validation Accuracy: 0.450200
# Epoch  3, CIFAR-10 Batch 2:  Loss:     1.5426 Validation Accuracy: 0.438600
# Epoch  3, CIFAR-10 Batch 3:  Loss:     1.2122 Validation Accuracy: 0.446800
# Epoch  3, CIFAR-10 Batch 4:  Loss:     1.5304 Validation Accuracy: 0.452200
# Epoch  3, CIFAR-10 Batch 5:  Loss:     1.4372 Validation Accuracy: 0.465200
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.6267 Validation Accuracy: 0.473600
# Epoch  4, CIFAR-10 Batch 2:  Loss:     1.3938 Validation Accuracy: 0.455600
# Epoch  4, CIFAR-10 Batch 3:  Loss:     1.1378 Validation Accuracy: 0.471000
# Epoch  4, CIFAR-10 Batch 4:  Loss:     1.4717 Validation Accuracy: 0.480200
# Epoch  4, CIFAR-10 Batch 5:  Loss:     1.4263 Validation Accuracy: 0.496600
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.5204 Validation Accuracy: 0.492000
# Epoch  5, CIFAR-10 Batch 2:  Loss:     1.3291 Validation Accuracy: 0.470600
# Epoch  5, CIFAR-10 Batch 3:  Loss:     1.1073 Validation Accuracy: 0.477600
# Epoch  5, CIFAR-10 Batch 4:  Loss:     1.3742 Validation Accuracy: 0.507600
# Epoch  5, CIFAR-10 Batch 5:  Loss:     1.3911 Validation Accuracy: 0.516000
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.4229 Validation Accuracy: 0.514400
# Epoch  6, CIFAR-10 Batch 2:  Loss:     1.2961 Validation Accuracy: 0.489800
# Epoch  6, CIFAR-10 Batch 3:  Loss:     1.0633 Validation Accuracy: 0.497000
# Epoch  6, CIFAR-10 Batch 4:  Loss:     1.3111 Validation Accuracy: 0.513400
# Epoch  6, CIFAR-10 Batch 5:  Loss:     1.3429 Validation Accuracy: 0.522600
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.3654 Validation Accuracy: 0.522800
# Epoch  7, CIFAR-10 Batch 2:  Loss:     1.2690 Validation Accuracy: 0.523600
# Epoch  7, CIFAR-10 Batch 3:  Loss:     1.0402 Validation Accuracy: 0.515400
# Epoch  7, CIFAR-10 Batch 4:  Loss:     1.2330 Validation Accuracy: 0.532600
# Epoch  7, CIFAR-10 Batch 5:  Loss:     1.3040 Validation Accuracy: 0.534800
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.2740 Validation Accuracy: 0.526000
# Epoch  8, CIFAR-10 Batch 2:  Loss:     1.2166 Validation Accuracy: 0.532000
# Epoch  8, CIFAR-10 Batch 3:  Loss:     0.9667 Validation Accuracy: 0.540800
# Epoch  8, CIFAR-10 Batch 4:  Loss:     1.1693 Validation Accuracy: 0.549400
# Epoch  8, CIFAR-10 Batch 5:  Loss:     1.2360 Validation Accuracy: 0.545000
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.1770 Validation Accuracy: 0.538400
# Epoch  9, CIFAR-10 Batch 2:  Loss:     1.1255 Validation Accuracy: 0.552800
# Epoch  9, CIFAR-10 Batch 3:  Loss:     0.9348 Validation Accuracy: 0.554000
# Epoch  9, CIFAR-10 Batch 4:  Loss:     1.1045 Validation Accuracy: 0.563400
# Epoch  9, CIFAR-10 Batch 5:  Loss:     1.2520 Validation Accuracy: 0.554600
# Epoch 10, CIFAR-10 Batch 1:  Loss:     1.1115 Validation Accuracy: 0.551800
# Epoch 10, CIFAR-10 Batch 2:  Loss:     1.0886 Validation Accuracy: 0.561000
# Epoch 10, CIFAR-10 Batch 3:  Loss:     0.8918 Validation Accuracy: 0.562400
# Epoch 10, CIFAR-10 Batch 4:  Loss:     1.0517 Validation Accuracy: 0.568000
# Epoch 10, CIFAR-10 Batch 5:  Loss:     1.1482 Validation Accuracy: 0.569000
# Epoch 11, CIFAR-10 Batch 1:  Loss:     1.0504 Validation Accuracy: 0.566000
# Epoch 11, CIFAR-10 Batch 2:  Loss:     1.0432 Validation Accuracy: 0.567800
# Epoch 11, CIFAR-10 Batch 3:  Loss:     0.8802 Validation Accuracy: 0.573600
# Epoch 11, CIFAR-10 Batch 4:  Loss:     1.0190 Validation Accuracy: 0.571400
# Epoch 11, CIFAR-10 Batch 5:  Loss:     1.1444 Validation Accuracy: 0.565800
# Epoch 12, CIFAR-10 Batch 1:  Loss:     1.0216 Validation Accuracy: 0.575200
# Epoch 12, CIFAR-10 Batch 2:  Loss:     0.9990 Validation Accuracy: 0.575400
# Epoch 12, CIFAR-10 Batch 3:  Loss:     0.8236 Validation Accuracy: 0.578800
# Epoch 12, CIFAR-10 Batch 4:  Loss:     0.9505 Validation Accuracy: 0.581200
# Epoch 12, CIFAR-10 Batch 5:  Loss:     1.0740 Validation Accuracy: 0.574800
# Epoch 13, CIFAR-10 Batch 1:  Loss:     0.9959 Validation Accuracy: 0.582600
# Epoch 13, CIFAR-10 Batch 2:  Loss:     0.9525 Validation Accuracy: 0.577400
# Epoch 13, CIFAR-10 Batch 3:  Loss:     0.7924 Validation Accuracy: 0.588400
# Epoch 13, CIFAR-10 Batch 4:  Loss:     0.9344 Validation Accuracy: 0.581400
# Epoch 13, CIFAR-10 Batch 5:  Loss:     1.0409 Validation Accuracy: 0.576000
# Epoch 14, CIFAR-10 Batch 1:  Loss:     0.9589 Validation Accuracy: 0.586800
# Epoch 14, CIFAR-10 Batch 2:  Loss:     0.9464 Validation Accuracy: 0.592400
# Epoch 14, CIFAR-10 Batch 3:  Loss:     0.7977 Validation Accuracy: 0.587200
# Epoch 14, CIFAR-10 Batch 4:  Loss:     0.8882 Validation Accuracy: 0.590400
# Epoch 14, CIFAR-10 Batch 5:  Loss:     1.0073 Validation Accuracy: 0.586600
# Epoch 15, CIFAR-10 Batch 1:  Loss:     0.8952 Validation Accuracy: 0.595600
# Epoch 15, CIFAR-10 Batch 2:  Loss:     0.9085 Validation Accuracy: 0.594800
# Epoch 15, CIFAR-10 Batch 3:  Loss:     0.7493 Validation Accuracy: 0.591200
# Epoch 15, CIFAR-10 Batch 4:  Loss:     0.8554 Validation Accuracy: 0.590600
# Epoch 15, CIFAR-10 Batch 5:  Loss:     0.9935 Validation Accuracy: 0.593800
# Epoch 16, CIFAR-10 Batch 1:  Loss:     0.8499 Validation Accuracy: 0.603400
# Epoch 16, CIFAR-10 Batch 2:  Loss:     0.9145 Validation Accuracy: 0.594400
# Epoch 16, CIFAR-10 Batch 3:  Loss:     0.7260 Validation Accuracy: 0.596200
# Epoch 16, CIFAR-10 Batch 4:  Loss:     0.8319 Validation Accuracy: 0.603000
# Epoch 16, CIFAR-10 Batch 5:  Loss:     0.9655 Validation Accuracy: 0.591400
# Epoch 17, CIFAR-10 Batch 1:  Loss:     0.8315 Validation Accuracy: 0.604000
# Epoch 17, CIFAR-10 Batch 2:  Loss:     0.8501 Validation Accuracy: 0.606800
# Epoch 17, CIFAR-10 Batch 3:  Loss:     0.7165 Validation Accuracy: 0.598400
# Epoch 17, CIFAR-10 Batch 4:  Loss:     0.8035 Validation Accuracy: 0.601600
# Epoch 17, CIFAR-10 Batch 5:  Loss:     0.9424 Validation Accuracy: 0.590800
# Epoch 18, CIFAR-10 Batch 1:  Loss:     0.7872 Validation Accuracy: 0.610000
# Epoch 18, CIFAR-10 Batch 2:  Loss:     0.8369 Validation Accuracy: 0.609800
# Epoch 18, CIFAR-10 Batch 3:  Loss:     0.6964 Validation Accuracy: 0.600800
# Epoch 18, CIFAR-10 Batch 4:  Loss:     0.7852 Validation Accuracy: 0.600400
# Epoch 18, CIFAR-10 Batch 5:  Loss:     0.9310 Validation Accuracy: 0.595000
# Epoch 19, CIFAR-10 Batch 1:  Loss:     0.7705 Validation Accuracy: 0.609400
# Epoch 19, CIFAR-10 Batch 2:  Loss:     0.8102 Validation Accuracy: 0.607600
# Epoch 19, CIFAR-10 Batch 3:  Loss:     0.6975 Validation Accuracy: 0.600000
# Epoch 19, CIFAR-10 Batch 4:  Loss:     0.7555 Validation Accuracy: 0.599600
# Epoch 19, CIFAR-10 Batch 5:  Loss:     0.8886 Validation Accuracy: 0.593800
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.7411 Validation Accuracy: 0.610400
# Epoch 20, CIFAR-10 Batch 2:  Loss:     0.7960 Validation Accuracy: 0.607800
# Epoch 20, CIFAR-10 Batch 3:  Loss:     0.6711 Validation Accuracy: 0.598400
# Epoch 20, CIFAR-10 Batch 4:  Loss:     0.7348 Validation Accuracy: 0.607800
# Epoch 20, CIFAR-10 Batch 5:  Loss:     0.8429 Validation Accuracy: 0.596600
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.7470 Validation Accuracy: 0.610800
# Epoch 21, CIFAR-10 Batch 2:  Loss:     0.7864 Validation Accuracy: 0.607200
# Epoch 21, CIFAR-10 Batch 3:  Loss:     0.6726 Validation Accuracy: 0.602400
# Epoch 21, CIFAR-10 Batch 4:  Loss:     0.7068 Validation Accuracy: 0.608600
# Epoch 21, CIFAR-10 Batch 5:  Loss:     0.8530 Validation Accuracy: 0.598600
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.7347 Validation Accuracy: 0.611800
# Epoch 22, CIFAR-10 Batch 2:  Loss:     0.7536 Validation Accuracy: 0.606800
# Epoch 22, CIFAR-10 Batch 3:  Loss:     0.6274 Validation Accuracy: 0.607600
# Epoch 22, CIFAR-10 Batch 4:  Loss:     0.6941 Validation Accuracy: 0.618800
# Epoch 22, CIFAR-10 Batch 5:  Loss:     0.7998 Validation Accuracy: 0.590800
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.7014 Validation Accuracy: 0.616400
# Epoch 23, CIFAR-10 Batch 2:  Loss:     0.7427 Validation Accuracy: 0.606800
# Epoch 23, CIFAR-10 Batch 3:  Loss:     0.6277 Validation Accuracy: 0.605200
# Epoch 23, CIFAR-10 Batch 4:  Loss:     0.6834 Validation Accuracy: 0.621200
# Epoch 23, CIFAR-10 Batch 5:  Loss:     0.7664 Validation Accuracy: 0.594600
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.6759 Validation Accuracy: 0.619200
# Epoch 24, CIFAR-10 Batch 2:  Loss:     0.7151 Validation Accuracy: 0.606600
# Epoch 24, CIFAR-10 Batch 3:  Loss:     0.6149 Validation Accuracy: 0.611800
# Epoch 24, CIFAR-10 Batch 4:  Loss:     0.6434 Validation Accuracy: 0.622600
# Epoch 24, CIFAR-10 Batch 5:  Loss:     0.7162 Validation Accuracy: 0.602800
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.6503 Validation Accuracy: 0.617000
# Epoch 25, CIFAR-10 Batch 2:  Loss:     0.7001 Validation Accuracy: 0.606800
# Epoch 25, CIFAR-10 Batch 3:  Loss:     0.6110 Validation Accuracy: 0.612600
# Epoch 25, CIFAR-10 Batch 4:  Loss:     0.6307 Validation Accuracy: 0.628800
# Epoch 25, CIFAR-10 Batch 5:  Loss:     0.7086 Validation Accuracy: 0.602200
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.6496 Validation Accuracy: 0.615800
# Epoch 26, CIFAR-10 Batch 2:  Loss:     0.6999 Validation Accuracy: 0.610800
# Epoch 26, CIFAR-10 Batch 3:  Loss:     0.6106 Validation Accuracy: 0.617400
# Epoch 26, CIFAR-10 Batch 4:  Loss:     0.6376 Validation Accuracy: 0.622200
# Epoch 26, CIFAR-10 Batch 5:  Loss:     0.6717 Validation Accuracy: 0.603400
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.6306 Validation Accuracy: 0.617200
# Epoch 27, CIFAR-10 Batch 2:  Loss:     0.6905 Validation Accuracy: 0.613600
# Epoch 27, CIFAR-10 Batch 3:  Loss:     0.5993 Validation Accuracy: 0.616000
# Epoch 27, CIFAR-10 Batch 4:  Loss:     0.6245 Validation Accuracy: 0.625000
# Epoch 27, CIFAR-10 Batch 5:  Loss:     0.6451 Validation Accuracy: 0.605400
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.6235 Validation Accuracy: 0.620600
# Epoch 28, CIFAR-10 Batch 2:  Loss:     0.6851 Validation Accuracy: 0.616200
# Epoch 28, CIFAR-10 Batch 3:  Loss:     0.5969 Validation Accuracy: 0.621600
# Epoch 28, CIFAR-10 Batch 4:  Loss:     0.6531 Validation Accuracy: 0.622800
# Epoch 28, CIFAR-10 Batch 5:  Loss:     0.6171 Validation Accuracy: 0.605400
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.6248 Validation Accuracy: 0.625000
# Epoch 29, CIFAR-10 Batch 2:  Loss:     0.6316 Validation Accuracy: 0.619200
# Epoch 29, CIFAR-10 Batch 3:  Loss:     0.5895 Validation Accuracy: 0.618600
# Epoch 29, CIFAR-10 Batch 4:  Loss:     0.5946 Validation Accuracy: 0.621200
# Epoch 29, CIFAR-10 Batch 5:  Loss:     0.5753 Validation Accuracy: 0.601400
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.6276 Validation Accuracy: 0.629000
# Epoch 30, CIFAR-10 Batch 2:  Loss:     0.6705 Validation Accuracy: 0.619000
# Epoch 30, CIFAR-10 Batch 3:  Loss:     0.5657 Validation Accuracy: 0.615200
# Epoch 30, CIFAR-10 Batch 4:  Loss:     0.5949 Validation Accuracy: 0.625200
# Epoch 30, CIFAR-10 Batch 5:  Loss:     0.5810 Validation Accuracy: 0.603600
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.6106 Validation Accuracy: 0.625600
# Epoch 31, CIFAR-10 Batch 2:  Loss:     0.6417 Validation Accuracy: 0.621800
# Epoch 31, CIFAR-10 Batch 3:  Loss:     0.5382 Validation Accuracy: 0.613800
# Epoch 31, CIFAR-10 Batch 4:  Loss:     0.5550 Validation Accuracy: 0.627000
# Epoch 31, CIFAR-10 Batch 5:  Loss:     0.5833 Validation Accuracy: 0.599000
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.6023 Validation Accuracy: 0.629400
# Epoch 32, CIFAR-10 Batch 2:  Loss:     0.6860 Validation Accuracy: 0.622200
# Epoch 32, CIFAR-10 Batch 3:  Loss:     0.5269 Validation Accuracy: 0.606200
# Epoch 32, CIFAR-10 Batch 4:  Loss:     0.5627 Validation Accuracy: 0.631400
# Epoch 32, CIFAR-10 Batch 5:  Loss:     0.5952 Validation Accuracy: 0.600800
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.5778 Validation Accuracy: 0.624600
# Epoch 33, CIFAR-10 Batch 2:  Loss:     0.6906 Validation Accuracy: 0.623600
# Epoch 33, CIFAR-10 Batch 3:  Loss:     0.5365 Validation Accuracy: 0.610400
# Epoch 33, CIFAR-10 Batch 4:  Loss:     0.5377 Validation Accuracy: 0.627800
# Epoch 33, CIFAR-10 Batch 5:  Loss:     0.5348 Validation Accuracy: 0.604000
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.5791 Validation Accuracy: 0.627800
# Epoch 34, CIFAR-10 Batch 2:  Loss:     0.6460 Validation Accuracy: 0.620000
# Epoch 34, CIFAR-10 Batch 3:  Loss:     0.5113 Validation Accuracy: 0.606600
# Epoch 34, CIFAR-10 Batch 4:  Loss:     0.5180 Validation Accuracy: 0.619600
# Epoch 34, CIFAR-10 Batch 5:  Loss:     0.5329 Validation Accuracy: 0.613000
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.5571 Validation Accuracy: 0.629600
# Epoch 35, CIFAR-10 Batch 2:  Loss:     0.6577 Validation Accuracy: 0.622800
# Epoch 35, CIFAR-10 Batch 3:  Loss:     0.4880 Validation Accuracy: 0.611200
# Epoch 35, CIFAR-10 Batch 4:  Loss:     0.4750 Validation Accuracy: 0.625000
# Epoch 35, CIFAR-10 Batch 5:  Loss:     0.5437 Validation Accuracy: 0.612400
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.5761 Validation Accuracy: 0.629400
# Epoch 36, CIFAR-10 Batch 2:  Loss:     0.6091 Validation Accuracy: 0.624400
# Epoch 36, CIFAR-10 Batch 3:  Loss:     0.4602 Validation Accuracy: 0.608600
# Epoch 36, CIFAR-10 Batch 4:  Loss:     0.5027 Validation Accuracy: 0.623000
# Epoch 36, CIFAR-10 Batch 5:  Loss:     0.5015 Validation Accuracy: 0.616800
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.5933 Validation Accuracy: 0.628000
# Epoch 37, CIFAR-10 Batch 2:  Loss:     0.6427 Validation Accuracy: 0.624200
# Epoch 37, CIFAR-10 Batch 3:  Loss:     0.4185 Validation Accuracy: 0.607400
# Epoch 37, CIFAR-10 Batch 4:  Loss:     0.4648 Validation Accuracy: 0.625600
# Epoch 37, CIFAR-10 Batch 5:  Loss:     0.5135 Validation Accuracy: 0.619400
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.5832 Validation Accuracy: 0.630400
# Epoch 38, CIFAR-10 Batch 2:  Loss:     0.5986 Validation Accuracy: 0.623800
# Epoch 38, CIFAR-10 Batch 3:  Loss:     0.4428 Validation Accuracy: 0.608400
# Epoch 38, CIFAR-10 Batch 4:  Loss:     0.4602 Validation Accuracy: 0.622600
# Epoch 38, CIFAR-10 Batch 5:  Loss:     0.4864 Validation Accuracy: 0.622400
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.5472 Validation Accuracy: 0.627400
# Epoch 39, CIFAR-10 Batch 2:  Loss:     0.6161 Validation Accuracy: 0.626200
# Epoch 39, CIFAR-10 Batch 3:  Loss:     0.4144 Validation Accuracy: 0.611400
# Epoch 39, CIFAR-10 Batch 4:  Loss:     0.4658 Validation Accuracy: 0.622400
# Epoch 39, CIFAR-10 Batch 5:  Loss:     0.4950 Validation Accuracy: 0.623600
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.5541 Validation Accuracy: 0.631400
# Epoch 40, CIFAR-10 Batch 2:  Loss:     0.5802 Validation Accuracy: 0.625600
# Epoch 40, CIFAR-10 Batch 3:  Loss:     0.4163 Validation Accuracy: 0.607600
# Epoch 40, CIFAR-10 Batch 4:  Loss:     0.4446 Validation Accuracy: 0.624800
# Epoch 40, CIFAR-10 Batch 5:  Loss:     0.5074 Validation Accuracy: 0.618200
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.5438 Validation Accuracy: 0.630400
# Epoch 41, CIFAR-10 Batch 2:  Loss:     0.5885 Validation Accuracy: 0.625200
# Epoch 41, CIFAR-10 Batch 3:  Loss:     0.4158 Validation Accuracy: 0.612800
# Epoch 41, CIFAR-10 Batch 4:  Loss:     0.4198 Validation Accuracy: 0.625000
# Epoch 41, CIFAR-10 Batch 5:  Loss:     0.4865 Validation Accuracy: 0.626000
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.5238 Validation Accuracy: 0.629800
# Epoch 42, CIFAR-10 Batch 2:  Loss:     0.5977 Validation Accuracy: 0.625200
# Epoch 42, CIFAR-10 Batch 3:  Loss:     0.4329 Validation Accuracy: 0.615200
# Epoch 42, CIFAR-10 Batch 4:  Loss:     0.4429 Validation Accuracy: 0.628200
# Epoch 42, CIFAR-10 Batch 5:  Loss:     0.4971 Validation Accuracy: 0.629800
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.5164 Validation Accuracy: 0.626000
# Epoch 43, CIFAR-10 Batch 2:  Loss:     0.5776 Validation Accuracy: 0.628000
# Epoch 43, CIFAR-10 Batch 3:  Loss:     0.3971 Validation Accuracy: 0.617200
# Epoch 43, CIFAR-10 Batch 4:  Loss:     0.4161 Validation Accuracy: 0.622400
# Epoch 43, CIFAR-10 Batch 5:  Loss:     0.4775 Validation Accuracy: 0.626600
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.5277 Validation Accuracy: 0.630600
# Epoch 44, CIFAR-10 Batch 2:  Loss:     0.5641 Validation Accuracy: 0.628600
# Epoch 44, CIFAR-10 Batch 3:  Loss:     0.3930 Validation Accuracy: 0.617600
# Epoch 44, CIFAR-10 Batch 4:  Loss:     0.4231 Validation Accuracy: 0.624600
# Epoch 44, CIFAR-10 Batch 5:  Loss:     0.4693 Validation Accuracy: 0.628600
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.5341 Validation Accuracy: 0.628800
# Epoch 45, CIFAR-10 Batch 2:  Loss:     0.5553 Validation Accuracy: 0.627800
# Epoch 45, CIFAR-10 Batch 3:  Loss:     0.3837 Validation Accuracy: 0.614000
# Epoch 45, CIFAR-10 Batch 4:  Loss:     0.4018 Validation Accuracy: 0.626600
# Epoch 45, CIFAR-10 Batch 5:  Loss:     0.4405 Validation Accuracy: 0.627800
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.5006 Validation Accuracy: 0.626400
# Epoch 46, CIFAR-10 Batch 2:  Loss:     0.5352 Validation Accuracy: 0.628800
# Epoch 46, CIFAR-10 Batch 3:  Loss:     0.3993 Validation Accuracy: 0.621000
# Epoch 46, CIFAR-10 Batch 4:  Loss:     0.4125 Validation Accuracy: 0.626200
# Epoch 46, CIFAR-10 Batch 5:  Loss:     0.4335 Validation Accuracy: 0.631400
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.4773 Validation Accuracy: 0.630200
# Epoch 47, CIFAR-10 Batch 2:  Loss:     0.5601 Validation Accuracy: 0.629000
# Epoch 47, CIFAR-10 Batch 3:  Loss:     0.3717 Validation Accuracy: 0.614000
# Epoch 47, CIFAR-10 Batch 4:  Loss:     0.3988 Validation Accuracy: 0.625400
# Epoch 47, CIFAR-10 Batch 5:  Loss:     0.4446 Validation Accuracy: 0.631200
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.4982 Validation Accuracy: 0.627200
# Epoch 48, CIFAR-10 Batch 2:  Loss:     0.5759 Validation Accuracy: 0.628400
# Epoch 48, CIFAR-10 Batch 3:  Loss:     0.3796 Validation Accuracy: 0.616800
# Epoch 48, CIFAR-10 Batch 4:  Loss:     0.3766 Validation Accuracy: 0.629200
# Epoch 48, CIFAR-10 Batch 5:  Loss:     0.4210 Validation Accuracy: 0.630200
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.4693 Validation Accuracy: 0.620800
# Epoch 49, CIFAR-10 Batch 2:  Loss:     0.5634 Validation Accuracy: 0.628200
# Epoch 49, CIFAR-10 Batch 3:  Loss:     0.3679 Validation Accuracy: 0.623800
# Epoch 49, CIFAR-10 Batch 4:  Loss:     0.3994 Validation Accuracy: 0.630000
# Epoch 49, CIFAR-10 Batch 5:  Loss:     0.4254 Validation Accuracy: 0.629400
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.4994 Validation Accuracy: 0.624600
# Epoch 50, CIFAR-10 Batch 2:  Loss:     0.5577 Validation Accuracy: 0.626600
# Epoch 50, CIFAR-10 Batch 3:  Loss:     0.3639 Validation Accuracy: 0.622000
# Epoch 50, CIFAR-10 Batch 4:  Loss:     0.3817 Validation Accuracy: 0.630000
# Epoch 50, CIFAR-10 Batch 5:  Loss:     0.4311 Validation Accuracy: 0.628200

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.6260878164556962

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. That's because there are many more techniques that can be applied to your model and we recemmond that once you are done with this project, you explore!
#
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
