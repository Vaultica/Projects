# %%
import spotipy
import pandas as pd

birdy_uri = 'spotify:artist:2WX2uTcsvV5OnS0inACecP'

sylvian_uri = 'spotify:artist:2oyWkw7sq99yqj12hVUHtw'

spotify = spotipy.Spotify()

results = spotify.artist_albums(birdy_uri, album_type='album')

print (results['items'])

albums = results['items']

while results['next']:
    results = spotify.next(results)
    albums.extend(results['items'])
# Out:
# [{'images': [{'width': 640, 'height': 640, 'url': 'https://i.scdn.co/image/afd3acff8667727320318741201ef412a20ca473'}, {'width': 300, 'height': 300, 'url': 'https://i.scdn.co/image/428b342a0fe84422864f4b145c7b88b01da1d7f0'}, {'width': 64, 'height': 64, 'url': 'https://i.scdn.co/image/23aaddf639aeb3d7ad27581e06056ca61533e972'}], 'id': '5wNnopxjgSKVvHTIcBpV8Q', 'name': 'Beautiful Lies', 'href': 'https://api.spotify.com/v1/albums/5wNnopxjgSKVvHTIcBpV8Q', 'available_markets': ['US'], 'artists': [{'id': '2WX2uTcsvV5OnS0inACecP', 'name': 'Birdy', 'href': 'https://api.spotify.com/v1/artists/2WX2uTcsvV5OnS0inACecP', 'uri': 'spotify:artist:2WX2uTcsvV5OnS0inACecP', 'external_urls': {'spotify': 'https://open.spotify.com/artist/2WX2uTcsvV5OnS0inACecP'}, 'type': 'artist'}], 'uri': 'spotify:album:5wNnopxjgSKVvHTIcBpV8Q', 'external_urls': {'spotify': 'https://open.spotify.com/album/5wNnopxjgSKVvHTIcBpV8Q'}, 'album_type': 'album', 'type': 'album'}, {'images': [{'width': 640, 'height': 640, 'url': 'https://i.scdn.co/image/afd3acff8667727320318741201ef412a20ca473'}, {'width': 300, 'height': 300, 'url': 'https://i.scdn.co/image/428b342a0fe84422864f4b145c7b88b01da1d7f0'}, {'width': 64, 'height': 64, 'url': 'https://i.scdn.co/image/23aaddf639aeb3d7ad27581e06056ca61533e972'}], 'id': '1UVggFtdVPqHy5WamYFu6w', 'name': 'Beautiful Lies', 'href': 'https://api.spotify.com/v1/albums/1UVggFtdVPqHy5WamYFu6w', 'available_markets': ['AD', 'AR', 'AU', 'BE', 'BG', 'BO', 'BR', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IS', 'IT', 'JP', 'LI', 'LT', 'LU', 'LV', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'SE', 'SG', 'SK', 'SV', 'TR', 'TW', 'UY'], 'artists': [{'id': '2WX2uTcsvV5OnS0inACecP', 'name': 'Birdy', 'href': 'https://api.spotify.com/v1/artists/2WX2uTcsvV5OnS0inACecP', 'uri': 'spotify:artist:2WX2uTcsvV5OnS0inACecP', 'external_urls': {'spotify': 'https://open.spotify.com/artist/2WX2uTcsvV5OnS0inACecP'}, 'type': 'artist'}], 'uri': 'spotify:album:1UVggFtdVPqHy5WamYFu6w', 'external_urls': {'spotify': 'https://open.spotify.com/album/1UVggFtdVPqHy5WamYFu6w'}, 'album_type': 'album', 'type': 'album'}, {'images': [{'width': 640, 'height': 640, 'url': 'https://i.scdn.co/image/afd3acff8667727320318741201ef412a20ca473'}, {'width': 300, 'height': 300, 'url': 'https://i.scdn.co/image/428b342a0fe84422864f4b145c7b88b01da1d7f0'}, {'width': 64, 'height': 64, 'url': 'https://i.scdn.co/image/23aaddf639aeb3d7ad27581e06056ca61533e972'}], 'id': '5TxrdDAUkipqcb4zGnnwkz', 'name': 'Beautiful Lies (Deluxe)', 'href': 'https://api.spotify.com/v1/albums/5TxrdDAUkipqcb4zGnnwkz', 'available_markets': ['AT', 'CH', 'DE'], 'artists': [{'id': '2WX2uTcsvV5OnS0inACecP', 'name': 'Birdy', 'href': 'https://api.spotify.com/v1/artists/2WX2uTcsvV5OnS0inACecP', 'uri': 'spotify:artist:2WX2uTcsvV5OnS0inACecP', 'external_urls': {'spotify': 'https://open.spotify.com/artist/2WX2uTcsvV5OnS0inACecP'}, 'type': 'artist'}], 'uri': 'spotify:album:5TxrdDAUkipqcb4zGnnwkz', 'external_urls': {'spotify': 'https://open.spotify.com/album/5TxrdDAUkipqcb4zGnnwkz'}, 'album_type': 'album', 'type': 'album'}, {'images': [{'width': 640, 'height': 640, 'url': 'https://i.scdn.co/image/afd3acff8667727320318741201ef412a20ca473'}, {'width': 300, 'height': 300, 'url': 'https://i.scdn.co/image/428b342a0fe84422864f4b145c7b88b01da1d7f0'}, {'width': 64, 'height': 64, 'url': 'https://i.scdn.co/image/23aaddf639aeb3d7ad27581e06056ca61533e972'}], 'id': '2uNFpEVey5RsxzTdoDmjiz', 'name': 'Beautiful Lies (Deluxe)', 'href': 'https://api.spotify.com/v1/albums/2uNFpEVey5RsxzTdoDmjiz', 'available_markets': ['AD', 'AR', 'AU', 'BE', 'BG', 'BO', 'BR', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'EC', 'EE', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IS', 'IT', 'JP', 'LI', 'LT', 'LU', 'LV', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'SE', 'SG', 'SK', 'SV', 'TR',  ...

# %%
for album in albums:
    print ("Album: {}, artists name: {}".format(album['artists'][0]['name']))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-e15947fdf766> in <module>()
#       1 for album in albums:
# ----> 2     print ("Album: {}, artists name: {}".format(album['artists'][0]['name']))
#
# IndexError: tuple index out of range

# %%
albums = pd.DataFrame(results['items'])
albums.head()
# Out:
#   album_type                                            artists  \
# 0      album  [{'id': '2WX2uTcsvV5OnS0inACecP', 'name': 'Bir...
# 1      album  [{'id': '2WX2uTcsvV5OnS0inACecP', 'name': 'Bir...
# 2      album  [{'id': '2WX2uTcsvV5OnS0inACecP', 'name': 'Bir...
# 3      album  [{'id': '2WX2uTcsvV5OnS0inACecP', 'name': 'Bir...
# 4      album  [{'id': '2WX2uTcsvV5OnS0inACecP', 'name': 'Bir...
#
#                                    available_markets  \
# 0  [AD, AR, AU, BE, BG, BO, BR, CA, CL, CO, CR, C...
# 1                                               [US]
# 2  [AD, AR, AU, BE, BG, BO, BR, CA, CL, CO, CR, C...
# 3                                       [AT, CH, DE]
# 4                                       [CA, ES, US]
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/album/1U...
# 1  {'spotify': 'https://open.spotify.com/album/5w...
# 2  {'spotify': 'https://open.spotify.com/album/2u...
# 3  {'spotify': 'https://open.spotify.com/album/5T...
# 4  {'spotify': 'https://open.spotify.com/album/0r...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/albums/1UVggFtdVPqH...  1UVggFtdVPqHy5WamYFu6w
# 1  https://api.spotify.com/v1/albums/5wNnopxjgSKV...  5wNnopxjgSKVvHTIcBpV8Q
# 2  https://api.spotify.com/v1/albums/2uNFpEVey5Rs...  2uNFpEVey5RsxzTdoDmjiz
# 3  https://api.spotify.com/v1/albums/5TxrdDAUkipq...  5TxrdDAUkipqcb4zGnnwkz
# 4  https://api.spotify.com/v1/albums/0r94AFhRLvpf...  0r94AFhRLvpfXvha7vx2dK
#
#                                               images                     name  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...           Beautiful Lies
# 1  [{'height': 640, 'url': 'https://i.scdn.co/ima...           Beautiful Lies
# 2  [{'height': 640, 'url': 'https://i.scdn.co/ima...  Beautiful Lies (Deluxe)
# 3  [{'height': 640, 'url': 'https://i.scdn.co/ima...  Beautiful Lies (Deluxe)
# 4  [{'height': 640, 'url': 'https://i.scdn.co/ima...              Fire Within
#
#     type                                   uri
# 0  album  spotify:album:1UVggFtdVPqHy5WamYFu6w
# 1  album  spotify:album:5wNnopxjgSKVvHTIcBpV8Q
# 2  album  spotify:album:2uNFpEVey5RsxzTdoDmjiz
# 3  album  spotify:album:5TxrdDAUkipqcb4zGnnwkz
# 4  album  spotify:album:0r94AFhRLvpfXvha7vx2dK

# %%
import spotipy
import pandas as pd
from pandas.io.json import json_normalize

def flatten_json(y):
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '_')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '_')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(y)
    return out

results = spotify.artist_albums(sylvian_uri, album_type='album')
results = spotify.artist_albums('spotify:artist:4I2BJf80C0skQpp1sQmA0h', album_type='album')

#res = json_normalize(results, ['artists', ['album_type', 'name', 'href']])
dic_flattened = [flatten_json(d) for d in results['items']]
df = pd.DataFrame(dic_flattened)
df.columns
df[['album_type' ,'artists_0_name', 'name', 'type','id']].head(20)
# Out:
#    album_type     artists_0_name  \
# 0       album  Belle & Sebastian
# 1       album  Belle & Sebastian
# 2       album  Belle & Sebastian
# 3       album  Belle & Sebastian
# 4       album  Belle & Sebastian
# 5       album  Belle & Sebastian
# 6       album  Belle & Sebastian
# 7       album  Belle & Sebastian
# 8       album  Belle & Sebastian
# 9       album  Belle & Sebastian
# 10      album  Belle & Sebastian
# 11      album  Belle & Sebastian
# 12      album  Belle & Sebastian
# 13      album  Belle & Sebastian
# 14      album  Belle & Sebastian
# 15      album  Belle & Sebastian
# 16      album  Belle & Sebastian
# 17      album  Belle & Sebastian
# 18      album  Belle & Sebastian
# 19      album  Belle & Sebastian
#
#                                                  name   type  \
# 0                     The Jeepster Singles Collection  album
# 1                    Girls in Peacetime Want to Dance  album
# 2                 On Girls In Peacetime Want To Dance  album
# 3                                The Third Eye Centre  album
# 4                                The Third Eye Centre  album
# 5   Late Night Tales: Belle and Sebastian, Vol. 2 ...  album
# 6                                    Write About Love  album
# 7                                    Write About Love  album
# 8   The BBC Sessions: Live In Belfast 2001 (Bonus ...  album
# 9                                    The BBC Sessions  album
# 10                                   The BBC Sessions  album
# 11                                   The BBC Sessions  album
# 12                                   The BBC Sessions  album
# 13              Late Night Tales: Belle and Sebastian  album
# 14                                   The Life Pursuit  album
# 15                                   The Life Pursuit  album
# 16   If You're Feeling Sinister: Live At The Barbican  album
# 17                     Push Barman To Open Old Wounds  album
# 18                     Push Barman to Open Old Wounds  album
# 19                     Push Barman To Open Old Wounds  album
#
#                         id
# 0   3nHWEWYHZ7psKLjWXuZAka
# 1   3Gy0FCDIx9MoliXd3YcTBt
# 2   2Hb5eO5g1kkMVo5J2lAErP
# 3   5ux7O0dlaqx1HC6JNdeCEj
# 4   1JzPEL8STg1xAVLos19RG6
# 5   3xDa8phPJijprE5NqnhD0I
# 6   1dlWXOJNfwsUZQvqEl6tVX
# 7   13iVHOPq26YcY6kbTI09Jj
# 8   1C1FxZ0J4iQUBS5QBPwRXb
# 9   6Letcqid8YI37DiBhH1RhO
# 10  3kvB6yYJrJsBa5KiK0EIhi
# 11  5ArCM4PeWr14am73GNOvpl
# 12  2BHx0eofkMhnOcfGnBYXOx
# 13  2R6v6EjGh8jTjbFQK5AUFI
# 14  1hS6jLMAAtF4UDOucCewKR
# 15  0pqlfn0pAYDb2zassbbD6G
# 16  55qxLu5jt1mQ6SnjP8agvH
# 17  2V0IZqEgldNbKPxUZuS4y4
# 18  6l8tlcL7JOuG03fAAmcohv
# 19  5E1aS75EL1XSYfYceVUaOE

# %% [markdown]
# ** Authentication **
#
# Application: Playlists2Albums
#
# Client ID
# d2c92ddc265d4663a323756acffa52ba
#
# Client Secret
# 42f8409cbb3a4bca86554870193da884

# %%
import sys
import spotipy
import spotipy.util as util

scope = 'user-library-read'

if len(sys.argv) > 1:
    username = sys.argv[1]
else:
    print "Usage: %s username" % (sys.argv[0],)
    sys.exit()

token = util.prompt_for_user_token(username, scope)

if token:
    sp = spotipy.Spotify(auth=token)
    results = sp.current_user_saved_tracks()
    for item in results['items']:
        track = item['track']
        print track['name'] + ' - ' + track['artists'][0]['name']
else:
    print "Can't get token for", username

# %%
import spotipy
spotify = spotipy.Spotify()
results = spotify.search(q='artist:' + name, type='artist')
print (results)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /Users/sergeboo/Software/anaconda3/lib/python3.5/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     106         try:
# --> 107             r.raise_for_status()
#     108         except:
#
# /Users/sergeboo/Software/anaconda3/lib/python3.5/site-packages/requests/models.py in raise_for_status(self)
#     861         if http_error_msg:
# --> 862             raise HTTPError(http_error_msg, response=self)
#     863
#
# HTTPError: 404 Client Error: Not Found for url: https://api.spotify.com/v1/search?type=artist&offset=0&limit=10&q=artist%3A-f+%2FUsers%2Fsergeboo%2FLibrary%2FJupyter%2Fruntime%2Fkernel-2afd357b-51f4-4d97-8a54-75ef5ff7840c.json
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# <ipython-input-10-725e9cb1e35a> in <module>()
#       1 import spotipy
#       2 spotify = spotipy.Spotify()
# ----> 3 results = spotify.search(q='artist:' + name, type='artist')
#       4 print (results)
#
# /Users/sergeboo/Software/anaconda3/lib/python3.5/site-packages/spotipy/client.py in search(self, q, limit, offset, type)
#     321                          'track' or 'playlist'
#     322         '''
# --> 323         return self._get('search', q=q, limit=limit, offset=offset, type=type)
#     324
#     325     def user(self, user):
#
# /Users/sergeboo/Software/anaconda3/lib/python3.5/site-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     131         while retries > 0:
#     132             try:
# --> 133                 return self._internal_call('GET', url, payload, kwargs)
#     134             except SpotifyException as e:
#     135                 retries -= 1
#
# /Users/sergeboo/Software/anaconda3/lib/python3.5/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     109             if r.text and len(r.text) > 0 and r.text != 'null':
#     110                 raise SpotifyException(r.status_code,
# --> 111                     -1, '%s:\n %s' % (r.url, r.json()['error']['message']))
#     112             else:
#     113                 raise SpotifyException(r.status_code,
#
# SpotifyException: http status: 404, code:-1 - https://api.spotify.com/v1/search?type=artist&offset=0&limit=10&q=artist%3A-f+%2FUsers%2Fsergeboo%2FLibrary%2FJupyter%2Fruntime%2Fkernel-2afd357b-51f4-4d97-8a54-75ef5ff7840c.json:
#  Not found.

# %%
import sys
import spotipy

''' shows the albums and tracks for a given artist.
'''

def get_artist(name):
    results = sp.search(q='artist:' + name, type='artist')
    items = results['artists']['items']
    if len(items) > 0:
        return items[0]
    else:
        return None

def show_artist_albums(artist):
    albums = []
    results = sp.artist_albums(artist['id'], album_type='album')
    albums.extend(results['items'])
    while results['next']:
        results = sp.next(results)
        albums.extend(results['items'])
    seen = set() # to avoid dups
    albums.sort(key=lambda album:album['name'].lower())
    for album in albums:
        name = album['name']
        if name not in seen:
            print((' ' + name))
            seen.add(name)

if __name__ == '__main__':
    sp = spotipy.Spotify()

    if len(sys.argv) < 2:
        print(('Usage: {0} artist name'.format(sys.argv[0])))
    else:
        name = ' '.join(sys.argv[1:])
        artist = get_artist(name)
        if artist:
            show_artist_albums(artist)
        else:
            print("Can't find that artist")
